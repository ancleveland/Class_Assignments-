# %%
# Dependencies
import json
import requests 
from pprint import pprint

# %%
# Specify the URL
url = "http://nyt-mongo-scraper.herokuapp.com/api/headlines"

# Make request and store response
response = requests.get(url)

# Print status code
print(response.status_code)
# Out:
# 200

# %%
# JSON-ify response
response_json = response.json()

# %%
pprint(response_json)
# Out:
# [{'__v': 0,
#   '_id': '5d800984a4315f0015223e22',
#   'date': '2019-09-16T22:15:32.326Z',
#   'headline': 'Where Mexican Folk Ballads Meet Trap Music',
#   'saved': True,
#   'summary': '“Trapcorridos” — tales of love, bandits, heroes and gangsters — '
#              'are a sensation in California and Mexico.',
#   'url': 'https://www.nytimes.com/2019/09/16/style/trapcorridos-chicano-los-angeles.html'},
#  {'__v': 0,
#   '_id': '5d800984a4315f0015223e23',
#   'date': '2019-09-16T22:15:32.326Z',
#   'headline': '‘He Stared at the Screen, and Then His Shoulders Slumped’',
#   'saved': True,
#   'summary': 'Sympathetic words in an elevator, a sign from above and more '
#              'reader tales of New York City in this week’s Metropolitan Diary.',
#   'url': 'https://www.nytimes.com/2019/09/15/nyregion/metropolitan-diary.html'},
#  {'__v': 0,
#   '_id': '5d800984a4315f0015223e1f',
#   'date': '2019-09-16T22:15:32.325Z',
#   'headline': 'A Battlefield View of U.S. Strategy in Afghanistan',
#   'saved': True,
#   'summary': '“Even as we want it all to stop, we know on one level that it '
#              'won’t.” Our reporter, a Marine who fought in Afghanistan, '
#              'reflects on an unending war.',
#   'url': 'https://www.nytimes.com/2019/09/16/world/middleeast/marja-trump-taliban-afghanistan-peace.html'},
#  {'__v': 0,
#   '_id': '5d800984a4315f0015223e1d',
#   'date': '2019-09-16T22:15:32.325Z',
#   'headline': 'Age Isn’t Hurting 2020 Democratic Leaders, to Rivals’ '
#               'ChagrinElizabeth Warren is holding a rally in Manhattan tonight '
#               'to deliver a speech on battling corruption.',
#   'saved': True,
#   'summary': 'Younger candidates are running as agents of generational change, '
#              'but it is three septuagenarians who have emerged as the '
#              'front-runners. And age-related attacks have not worked.',
#   'url': 'https://www.nytimes.com/2019/09/16/us/politics/democrats-biden-2020-age.html'},
#  {'__v': 0,
#   '_id': '5d800984a4315f0015223e20',
#   'date': '2019-09-16T22:15:32.325Z',
#   'headline': 'The Cost of Running Guantánamo Bay: $13 Million Per Prisoner',
#   'saved': True,
#   'summary': 'Set up nearly 18 years ago to house detainees in the war on '
#              'terrorism, the prison on the remote naval base has grown into '
#              'what appears to be the most expensive on earth.',
#   'url': 'https://www.nytimes.com/2019/09/16/us/politics/guantanamo-bay-cost-prison.html'},
#  {'__v': 0,
#   '_id': '5d800984a4315f0015223e1e',
#   'date': '2019-09-16T22:15:32.325Z',
#   'headline': 'Senator Alerted F.B.I. to New Kavanaugh Allegation8 Years of '
#               'Trump Tax Returns Are Subpoenaed by Manhattan D.A.',
#   'saved': True,
#   'summary': 'A Democratic senator expressed concern last year that the F.B.I. '
#              'was not following up on allegations against the Supreme Court '
#              'nominee.Investigators demanded President Trump’s personal and '
#              'corporate tax returns as they examine hush money paid to Stormy '
#              'Daniels.',
#   'url': 'https://www.nytimes.com/2019/09/16/us/politics/kavanaugh-fbi.html'},
#  {'__v': 0,
#   '_id': '5d800984a4315f0015223e1c',
#   'date': '2019-09-16T22:15:32.324Z',
#   'headline': 'Why This Scientist Keeps Receiving Packages of Serial Killers’ '
#               'Hair',
#   'saved': True,
#   'summary': 'Getting sufficient DNA out of a rootless hair has long been '
#              'considered impossible. A scientist known for work with ancient '
#              'fossils figured it out.',
#   'url': 'https://www.nytimes.com/2019/09/16/science/hair-dna-murder.html'},
#  {'__v': 0,
#   '_id': '5d800984a4315f0015223e1b',
#   'date': '2019-09-16T22:15:32.324Z',
#   'headline': 'G.M. Hit With Nationwide Strike by 50,000 AutoworkersHere are '
#               'answers to key questions about the General Motors strike.',
#   'saved': True,
#   'summary': 'The union wants wages raised and idled plants reopened. The '
#              'company wants employees to pay a greater portion of their health '
#              'care costs.',
#   'url': 'https://www.nytimes.com/2019/09/15/business/autoworkers-union-general-motors.html'},
#  {'__v': 0,
#   '_id': '5d800984a4315f0015223e1a',
#   'date': '2019-09-16T22:15:32.322Z',
#   'headline': 'Attacks Put Oil Market on Edge: ‘What if the Other Shoe Drops?’',
#   'saved': True,
#   'summary': 'Supply disruptions and the risk of future attacks are likely to '
#              'prop up energy prices, benefiting the industry and hurting '
#              'consumers.',
#   'url': 'https://www.nytimes.com/2019/09/16/business/oil-prices-markets.html'},
#  {'__v': 0,
#   '_id': '5d7fcca3b87d810015a74477',
#   'date': '2019-09-16T17:55:47.424Z',
#   'headline': 'Pam Grier on Maintaining Independence and Identity',
#   'saved': True,
#   'summary': '“The power of ‘no’ is one thing I’ve learned,” the actress said '
#              'about surviving in show business.',
#   'url': 'https://www.nytimes.com/interactive/2019/09/15/magazine/pam-grier-interview.html'},
#  {'__v': 0,
#   '_id': '5d7fcca3b87d810015a74476',
#   'date': '2019-09-16T17:55:47.424Z',
#   'headline': 'He Was the Netflix C.E.O. Before ‘Netflix and Chill’',
#   'saved': True,
#   'summary': 'A memoir by Marc Randolph, the company’s first boss, provides a '
#              'blast from the entertainment giant’s red-envelope past.',
#   'url': 'https://www.nytimes.com/2019/09/15/business/media/netflix-chief-executive-reed-hastings-marc-randolph.html'},
#  {'__v': 0,
#   '_id': '5d7fcca3b87d810015a74473',
#   'date': '2019-09-16T17:55:47.423Z',
#   'headline': 'Democrats’ Afghan Strategy Sounds Familiar. It’s a Lot Like '
#               'Trump’s.Working Families Party Endorses Warren',
#   'saved': False,
#   'summary': 'Candidates have one major goal for Afghanistan: Get out. They '
#              'are struggling to differentiate themselves from President '
#              'Trump’s view of American power.The progressive group, whose '
#              'influence has grown since it backed Senator Bernie Sanders in '
#              '2016, is supporting Senator Elizabeth Warren.',
#   'url': 'https://www.nytimes.com/2019/09/16/us/politics/2020-democrats-afghanistan.html'},
#  {'__v': 0,
#   '_id': '5d7fcca3b87d810015a74470',
#   'date': '2019-09-16T17:55:47.422Z',
#   'headline': 'G.M. Hit With Nationwide Strike by 50,000 AutoworkersHere are '
#               'answers to four key questions about the General Motors strike.',
#   'saved': False,
#   'summary': 'The union wants wages raised and idled plants reopened. The '
#              'company wants employees to pay a greater portion of their health '
#              'care costs.',
#   'url': 'https://www.nytimes.com/2019/09/15/business/autoworkers-union-general-motors.html'},
#  {'__v': 0,
#   '_id': '5d7fcca3b87d810015a74471',
#   'date': '2019-09-16T17:55:47.422Z',
#   'headline': 'The M.T.A.’s $54 Billion Plan to Transform Your Commute',
#   'saved': False,
#   'summary': 'Modern subway signals, new elevators and an extension of the '
#              'Second Avenue line: The New York City transit agency released '
#              'its five-year wish list.',
#   'url': 'https://www.nytimes.com/2019/09/16/nyregion/mta-budget-subway.html'},
#  {'__v': 0,
#   '_id': '5d7fa2f1b87d810015a7446b',
#   'date': '2019-09-16T14:57:53.762Z',
#   'headline': 'Biden Has Deep Connection to Black Voters. Will It Turn Into '
#               'Votes?Here are three questions (and answers) about Mr. Biden’s '
#               'candidacy.',
#   'saved': False,
#   'summary': 'Joe Biden leads among African-Americans, and older black voters '
#              'admire him. But it’s not “locked down,” one strategist said.',
#   'url': 'https://www.nytimes.com/2019/09/15/us/politics/joe-biden-black-voters.html'},
#  {'__v': 0,
#   '_id': '5d7fa2f1b87d810015a7446a',
#   'date': '2019-09-16T14:57:53.762Z',
#   'headline': 'Israeli Election Could Hinge on Ugly Breakup of an Odd '
#               'CoupleIsraelis will vote Tuesday for the second time in five '
#               'months. Will it be déjà vu or a chance for change?',
#   'saved': False,
#   'summary': 'For Prime Minister Benjamin Netanyahu and his former deputy '
#              'Avigdor Liberman, Israel’s do-over election will cap a love-hate '
#              'saga of three decades.',
#   'url': 'https://www.nytimes.com/2019/09/16/world/middleeast/netanyahu-liberman-israel-election.html'},
#  {'__v': 0,
#   '_id': '5d7fa2f1b87d810015a74466',
#   'date': '2019-09-16T14:57:53.761Z',
#   'headline': 'Houthi Forces in Yemen Warn of More Attacks on Saudi Oil '
#               'SystemsThe attacks had a short-term effect on prices, but a '
#               'severe shock to energy markets and the world economy is '
#               'unlikely.',
#   'saved': False,
#   'summary': 'American officials blamed Iran for the attacks that slashed '
#              'Saudi production, but the Houthi faction, allied with Iran, '
#              'claimed responsibility.',
#   'url': 'https://www.nytimes.com/2019/09/16/world/middleeast/houthis-yemen-saudi-arabia-warning.html'},
#  {'__v': 0,
#   '_id': '5d7f9193b87d810015a74465',
#   'date': '2019-09-16T13:43:47.331Z',
#   'headline': 'What We Learned in N.F.L. Week 2',
#   'saved': True,
#   'summary': 'Quarterbacks are fragile, referees are fallible and advice can '
#              'be dangerous. It was a fun but not particularly eventful week.',
#   'url': 'https://www.nytimes.com/2019/09/16/sports/football/nfl-week-2-scores.html'},
#  {'__v': 0,
#   '_id': '5d7f9193b87d810015a74463',
#   'date': '2019-09-16T13:43:47.330Z',
#   'headline': 'Where There Are Fish in the Tap Water and Women’s Uteruses Fall '
#               'Out',
#   'saved': False,
#   'summary': 'Daily life in the forgotten war zone of eastern Ukraine.',
#   'url': 'https://www.nytimes.com/2019/09/16/opinion/eastern-ukraine-russia-conflict-.html'},
#  {'__v': 0,
#   '_id': '5d7f9193b87d810015a74462',
#   'date': '2019-09-16T13:43:47.330Z',
#   'headline': '65 Block Parties, 5 Boroughs, 20 Photographers',
#   'saved': False,
#   'summary': 'Join New Yorkers from Brooklyn to the Bronx as they dance, eat '
#              'and play in the streets.',
#   'url': 'https://www.nytimes.com/interactive/2019/09/15/nyregion/block-parties-nyc.html'},
#  {'__v': 0,
#   '_id': '5d7f9193b87d810015a74464',
#   'date': '2019-09-16T13:43:47.330Z',
#   'headline': 'In Montauk, a Garden Runs Delightfully Amok',
#   'saved': False,
#   'summary': 'At their weekend home on the outer edge of Long Island, the '
#              'designers behind the firm Roman and Williams let nature lead.',
#   'url': 'https://www.nytimes.com/2019/09/16/t-magazine/roman-williams-garden.html'},
#  {'__v': 0,
#   '_id': '5d7f9193b87d810015a7445f',
#   'date': '2019-09-16T13:43:47.329Z',
#   'headline': 'Purdue Pharma Files for Chapter 11 Bankruptcy',
#   'saved': False,
#   'summary': 'The filing is a centerpiece of the settlement of thousands of '
#              'cases against the company for its role in the opioid crisis. It '
#              'is expected to be contested by many states.',
#   'url': 'https://www.nytimes.com/2019/09/15/health/purdue-pharma-bankruptcy-opioids-settlement.html'},
#  {'__v': 0,
#   '_id': '5d7f9193b87d810015a74460',
#   'date': '2019-09-16T13:43:47.329Z',
#   'headline': 'Ugly Breakup of Israel’s Odd Couple Could Turn an '
#               'ElectionIsraelis will vote on Tuesday for the second time in '
#               'five months. Will it be déjà vu or a chance for change?',
#   'saved': False,
#   'summary': 'For Prime Minister Benjamin Netanyahu and his former deputy '
#              'Avigdor Liberman, Israel’s do-over election will cap a love-hate '
#              'saga of three decades.',
#   'url': 'https://www.nytimes.com/2019/09/16/world/middleeast/netanyahu-liberman-israel-election.html'},
#  {'__v': 0,
#   '_id': '5d7f9193b87d810015a74461',
#   'date': '2019-09-16T13:43:47.329Z',
#   'headline': 'Biden Has Deep Ties to Black Voters. Will It Turn Into '
#               'Votes?Here are three questions (and answers) about Mr. Biden’s '
#               'candidacy.',
#   'saved': False,
#   'summary': 'Joe Biden leads among African-Americans, and older black voters '
#              'admire him. But it’s not “locked down,” one strategist said.',
#   'url': 'https://www.nytimes.com/2019/09/15/us/politics/joe-biden-black-voters.html'},
#  {'__v': 0,
#   '_id': '5d7f9193b87d810015a7445e',
#   'date': '2019-09-16T13:43:47.328Z',
#   'headline': 'Autoworkers’ Union Goes on Strike Against G.M.',
#   'saved': False,
#   'summary': 'Nearly 50,000 members at General Motors factories across the '
#              'Midwest and South are headed to the picket lines Monday morning.',
#   'url': 'https://www.nytimes.com/2019/09/15/business/autoworkers-union-general-motors.html'},
#  {'__v': 0,
#   '_id': '5d7f9193b87d810015a7445c',
#   'date': '2019-09-16T13:43:47.327Z',
#   'headline': 'Houthi Forces in Yemen Warn of More Attacks on Saudi Oil '
#               'SystemsThe attacks had a short-term impact on oil prices, but a '
#               'severe shock to energy markets and the world economy is '
#               'unlikely.',
#   'saved': False,
#   'summary': 'American officials have blamed Iran for the attacks that slashed '
#              'Saudi production, but the Houthi faction, allied with Iran, '
#              'claimed responsibility.',
#   'url': 'https://www.nytimes.com/2019/09/16/world/middleeast/houthis-yemen-saudi-arabia-warning.html'}]

# %%
# Print first and last articles
print(f"The first response is {json.dumps(response_json[0], indent=2)}.")
print(f"The last response is {json.dumps(response_json[-1], indent=2)}.")
# Out:
# The first response is {
#   "saved": true,
#   "_id": "5d800984a4315f0015223e22",
#   "headline": "Where Mexican Folk Ballads Meet Trap Music",
#   "summary": "\u201cTrapcorridos\u201d \u2014 tales of love, bandits, heroes and gangsters \u2014 are a sensation in California and Mexico.",
#   "url": "https://www.nytimes.com/2019/09/16/style/trapcorridos-chicano-los-angeles.html",
#   "date": "2019-09-16T22:15:32.326Z",
#   "__v": 0
# }.
# The last response is {
#   "saved": false,
#   "_id": "5d7f9193b87d810015a7445c",
#   "headline": "Houthi Forces in Yemen Warn of More Attacks on Saudi Oil SystemsThe attacks had a short-term impact on oil prices, but a severe shock to energy markets and the world economy is unlikely.",
#   "summary": "American officials have blamed Iran for the attacks that slashed Saudi production, but the Houthi faction, allied with Iran, claimed responsibility.",
#   "url": "https://www.nytimes.com/2019/09/16/world/middleeast/houthis-yemen-saudi-arabia-warning.html",
#   "date": "2019-09-16T13:43:47.327Z",
#   "__v": 0
# }.

# %%
#Print the number of responses received.
print(f"We received {len(response_json)} responses.")
# Out:
# We received 26 responses.
